# %%
number = 3+3
print("The total is:", number)
# Out:
# The total is: 6

# %%
name = "JMK"
print("Hello", name)
# Out:
# Hello JMK

# %%
for number in range(5):
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for letter in name:
    print(letter)
# Out:
# J
# M
# K

# %%
age = 6
if age < 5:
    print("free")
else:
    print("Buy a ticket")
    if age <= 18:
        print("Ticket price is 5€")
    elif  18 < age <= 50 :
        print("Ticket price is 10€")
    elif 50 < age:
        print("Ticket price is 5€")
# Out:
# Buy a ticket
# Ticket price is 5€

# %%
sentence = "memetsavennadoleme"
print(sentence[0:2],sentence[2:13],sentence[13:]) # if you leave the second slot empty it means it is to go till the end of the string

#Trying to get the last character
print(sentence[-5:-1])
#takes the first character of the substring
print(sentence[5:][0])
#First five letters, starting from 5
print(sentence[0:-13])
# Out:
# me metsavennad oleme
# olem
# s
# memet

# %%
Sentence = "Alice went to the park and saw a beautiful bird singing"

words = Sentence.split(" ") #splits the sentence into words by spaces

print(words)
print(words[0])
print(words[0:3])
# Out:
# ['Alice', 'went', 'to', 'the', 'park', 'and', 'saw', 'a', 'beautiful', 'bird', 'singing']
# Alice
# ['Alice', 'went', 'to']
